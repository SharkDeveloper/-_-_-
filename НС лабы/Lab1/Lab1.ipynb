# %%
import copy
import random
import numpy as np

# %% [markdown]
# Создания класса описывающий перцептрон Розенблата

# %%
class Perceptron:
  def __init__(self,epochs):
    self.weights = np.ones((2,1))
    self.epochs = epochs

  def creat_dataset(self):
    dataset = list()

    dataset.append(([0, 0], 0))
    dataset.append(([0, 1], 1))
    dataset.append(([1, 0], 1))
    dataset.append(([1, 1], 0))

    noise_dataset = list()
    for i in range(10000):
      noise_dataset.append(copy.deepcopy(random.choice(dataset)))
      for j in range(2):
        noise_dataset[i][0][j] += (random.randint(-45, 45) * 0.01)

    return noise_dataset

  def bin_classification(self,input_ind):
    ind = []
    if input_ind[0]-0.5 > 0:
      ind.append(1)
    else:
      ind.append(0)
    if input_ind[1]-0.5 > 0:
      ind.append(1)
    else:
      ind.append(0)
    return ind
  
  def summator(self,input_ind):
    summator = 0
    for i in range(2):
      summator += input_ind[i]*self.weights[i]
    if summator >0.5 and summator < 1.5:
      return True
    else:
      return False

  def learn(self):
    dataset = self.creat_dataset()
    for i in range(len(dataset)):
      if bool(dataset[i][1]) != self.summator(self.bin_classification(dataset[i][0])):
        self.weights[0][i] = self.weights[0][i]+0.1

  def train(self):
    for i in range(self.epochs):
      self.learn()

  def test(self,input_dataset,test_res):
    res = 0
    for i in range(len(input_dataset)):
      print(f"Входные данные {input_dataset[i]}    Предсказание: {self.summator(self.bin_classification(input_dataset[i]))}")
      if self.summator(self.bin_classification(input_dataset[i])) == test_res[i]:
        res+=1
    print(self.weights)
    print("Accurancy: ",res/len(test_res))

# %% [markdown]
# Запуск обучения модели

# %%
p = Perceptron(10)
p.train()

# %% [markdown]
# Формирование тренировочного датасета и добавление в него шума (-0.45 , 0.45)

# %%
test_data = list()
test_res = list()
dataset = list()
dataset.append(([0, 0],0))
dataset.append(([0, 1],1))
dataset.append(([1, 0],1))
dataset.append(([1, 1],0))
noise_dataset = list()
for i in range(5000):
  noise_dataset.append(copy.deepcopy(random.choice(dataset)))
  for j in range(2):
    noise_dataset[i][0][j] += (random.randint(-45, 45) * 0.01)
for ind in range(len(noise_dataset)):
  test_data.append(noise_dataset[ind][0])
  test_res.append(noise_dataset[ind][1])

# %% [markdown]
# Запуск проверки НС

# %%
p.test(test_data,test_res)
# Out:
# Входные данные [0.09, 0.76]    Предсказание: True
# Входные данные [-0.13, 0.91]    Предсказание: True
# Входные данные [0.06, 0.9299999999999999]    Предсказание: True
# Входные данные [0.7, -0.15]    Предсказание: True
# Входные данные [0.83, 0.4]    Предсказание: True
# Входные данные [0.34, -0.28]    Предсказание: False
# Входные данные [0.36, 0.7]    Предсказание: True
# Входные данные [1.23, 0.2]    Предсказание: True
# Входные данные [-0.45, 0.08]    Предсказание: False
# Входные данные [-0.44, 0.61]    Предсказание: True
# Входные данные [0.08, 0.99]    Предсказание: True
# Входные данные [1.16, 0.34]    Предсказание: True
# Входные данные [-0.34, 0.8200000000000001]    Предсказание: True
# Входные данные [0.6499999999999999, -0.3]    Предсказание: True
# Входные данные [1.42, 1.3]    Предсказание: False
# Входные данные [1.19, -0.21]    Предсказание: True
# Входные данные [0.23, 1.43]    Предсказание: True
# Входные данные [0.29, 0.5800000000000001]    Предсказание: True
# Входные данные [-0.01, 1.25]    Предсказание: True
# Входные данные [0.96, -0.39]    Предсказание: True
# Входные данные [-0.08, 0.92]    Предсказание: True
# Входные данные [0.86, 0.33]    Предсказание: True
# Входные данные [0.44, 1.15]    Предсказание: True
# Входные данные [0.29, 0.41000000000000003]    Предсказание: False
# Входные данные [-0.21, 0.8200000000000001]    Предсказание: True
# Входные данные [1.34, 0.08]    Предсказание: True
# Входные данные [0.24, 0.97]    Предсказание: True
# Входные данные [0.97, 0.1]    Предсказание: True
# Входные данные [0.41000000000000003, 0.29]    Предсказание: False
# Входные данные [-0.45, 0.56]    Предсказание: True
# Входные данные [0.3, -0.45]    Предсказание: False
# Входные данные [1.17, 0.92]    Предсказание: False
# Входные данные [1.16, 0.8200000000000001]    Предсказание: False
# Входные данные [1.18, 0.39]    Предсказание: True
# Входные данные [-0.15, -0.11]    Предсказание: False
# Входные данные [0.74, 1.07]    Предсказание: False
# Входные данные [0.91, -0.41000000000000003]    Предсказание: True
# Входные данные [0.2, 0.34]    Предсказание: False
# Входные данные [0.28, 0.5700000000000001]    Предсказание: True
# Входные данные [-0.35000000000000003, 0.23]    Предсказание: False
# Входные данные [0.11, -0.24]    Предсказание: False
# Входные данные [-0.36, 0.08]    Предсказание: False
# Входные данные [0.91, 0.1]    Предсказание: True
# Входные данные [-0.45, 1.34]    Предсказание: True
# Входные данные [0.42, 0.96]    Предсказание: True
# Входные данные [-0.33, 1.09]    Предсказание: True
# Входные данные [-0.17, 0.19]    Предсказание: False
# Входные данные [0.78, 0.18]    Предсказание: True
# Входные данные [-0.4, 0.78]    Предсказание: True
# Входные данные [-0.36, 0.44]    Предсказание: False
# Входные данные [0.36, 1.09]    Предсказание: True
# Входные данные [-0.41000000000000003, 0.16]    Предсказание: False
# Входные данные [0.5800000000000001, 1.28]    Предсказание: False
# Входные данные [-0.04, 0.18]    Предсказание: False
# Входные данные [0.11, 0.43]    Предсказание: False
# Входные данные [-0.45, 1.31]    Предсказание: True
# Входные данные [1.22, 0.83]    Предсказание: False
# Входные данные [0.61, 0.03]    Предсказание: True
# Входные данные [0.8, 0.98]    Предсказание: False
# Входные данные [1.34, -0.13]    Предсказание: True
# Входные данные [1.37, 0.71]    Предсказание: False
# Входные данные [1.45, 0.97]    Предсказание: False
# Входные данные [0.07, -0.38]    Предсказание: False
# Входные данные [-0.05, -0.34]    Предсказание: False
# Входные данные [1.3900000000000001, 1.01]    Предсказание: False
# Входные данные [0.97, 0.5800000000000001]    Предсказание: False
# Входные данные [1.4100000000000001, 0.75]    Предсказание: False
# Входные данные [1.4100000000000001, 0.88]    Предсказание: False
# Входные данные [1.34, 0.61]    Предсказание: False
# Входные данные [1.11, 0.5700000000000001]    Предсказание: False
# Входные данные [1.43, 0.72]    Предсказание: False
# Входные данные [0.6699999999999999, -0.15]    Предсказание: True
# Входные данные [0.16, 1.16]    Предсказание: True
# Входные данные [-0.11, 1.4100000000000001]    Предсказание: True
# Входные данные [0.6699999999999999, 0.97]    Предсказание: False
# Входные данные [0.94, 0.6599999999999999]    Предсказание: False
# Входные данные [1.29, -0.16]    Предсказание: True
# Входные данные [0.38, -0.19]    Предсказание: False
# Входные данные [-0.24, 0.6599999999999999]    Предсказание: True
# Входные данные [0.21, -0.17]    Предсказание: False
# Входные данные [1.3, 0.91]    Предсказание: False
# Входные данные [0.23, 0.19]    Предсказание: False
# Входные данные [0.24, 1.07]    Предсказание: True
# Входные данные [-0.37, 1.01]    Предсказание: True
# Входные данные [0.97, -0.28]    Предсказание: True
# Входные данные [0.01, 0.89]    Предсказание: True
# Входные данные [-0.44, 1.1]    Предсказание: True
# Входные данные [-0.29, -0.15]    Предсказание: False
# Входные данные [-0.35000000000000003, -0.45]    Предсказание: False
# Входные данные [0.09, 1.43]    Предсказание: True
# Входные данные [0.64, 0.43]    Предсказание: True
# Входные данные [0.0, -0.31]    Предсказание: False
# Входные данные [1.15, 1.29]    Предсказание: False
# Входные данные [1.01, 0.84]    Предсказание: False
# Входные данные [0.08, 0.5700000000000001]    Предсказание: True
# Входные данные [0.22, -0.32]    Предсказание: False
# Входные данные [0.72, -0.07]    Предсказание: True
# Входные данные [0.73, 0.79]    Предсказание: False
# Входные данные [1.3599999999999999, 0.0]    Предсказание: True
# Входные данные [0.6599999999999999, 0.61]    Предсказание: False
# Входные данные [1.26, 0.94]    Предсказание: False
# Входные данные [0.26, 0.6499999999999999]    Предсказание: True
# Входные данные [1.31, 0.09]    Предсказание: True
# Входные данные [0.69, -0.1]    Предсказание: True
# Входные данные [-0.3, 0.24]    Предсказание: False
# Входные данные [0.8, -0.4]    Предсказание: True
# Входные данные [-0.18, 1.25]    Предсказание: True
# Входные данные [0.6499999999999999, 1.26]    Предсказание: False
# Входные данные [0.98, -0.02]    Предсказание: True
# Входные данные [-0.35000000000000003, -0.41000000000000003]    Предсказание: False
# Входные данные [1.45, -0.23]    Предсказание: True
# Входные данные [0.91, -0.38]    Предсказание: True
# Входные данные [0.6, 1.27]    Предсказание: False
# Входные данные [0.88, -0.08]    Предсказание: True
# Входные данные [1.09, -0.45]    Предсказание: True
# Входные данные [1.32, -0.2]    Предсказание: True
# Входные данные [0.26, 1.13]    Предсказание: True
# Входные данные [-0.21, 1.04]    Предсказание: True
# Входные данные [0.5700000000000001, 0.6499999999999999]    Предсказание: False
# Входные данные [0.2, -0.28]    Предсказание: False
# Входные данные [-0.38, 0.5800000000000001]    Предсказание: True
# Входные данные [0.6599999999999999, 0.38]    Предсказание: True
# Входные данные [0.62, -0.42]    Предсказание: True
# Входные данные [0.74, 0.08]    Предсказание: True
# Входные данные [-0.21, 1.17]    Предсказание: True
# Входные данные [-0.09, 0.94]    Предсказание: True
# Входные данные [0.62, -0.32]    Предсказание: True
# Входные данные [0.69, 1.35]    Предсказание: False
# Входные данные [0.34, 0.6699999999999999]    Предсказание: True
# Входные данные [-0.32, 1.1400000000000001]    Предсказание: True
# Входные данные [-0.45, 1.33]    Предсказание: True
# Входные данные [0.36, 0.69]    Предсказание: True
# Входные данные [0.97, 0.71]    Предсказание: False
# Входные данные [1.04, 0.63]    Предсказание: False
# Входные данные [0.78, -0.39]    Предсказание: True
# Входные данные [0.29, 0.8200000000000001]    Предсказание: True
# Входные данные [-0.11, 0.43]    Предсказание: False
# Входные данные [-0.13, 0.91]    Предсказание: True
# Входные данные [0.9, 1.1]    Предсказание: False
# Входные данные [1.04, 0.6799999999999999]    Предсказание: False
# Входные данные [0.94, -0.11]    Предсказание: True
# Входные данные [-0.16, 0.73]    Предсказание: True
# Входные данные [0.5700000000000001, 0.32]    Предсказание: True
# Входные данные [0.11, 0.6699999999999999]    Предсказание: True
# Входные данные [-0.19, 0.62]    Предсказание: True
# Входные данные [0.71, -0.35000000000000003]    Предсказание: True
# Входные данные [0.56, 0.5700000000000001]    Предсказание: False
# Входные данные [0.28, 0.5700000000000001]    Предсказание: True
# Входные данные [1.27, 0.19]    Предсказание: True
# Входные данные [0.78, 0.62]    Предсказание: False
# Входные данные [0.37, -0.23]    Предсказание: False
# Входные данные [0.71, 0.03]    Предсказание: True
# Входные данные [0.73, 0.6]    Предсказание: False
# Входные данные [1.07, 0.72]    Предсказание: False
# Входные данные [1.13, 0.78]    Предсказание: False
# Входные данные [-0.26, 0.12]    Предсказание: False
# Входные данные [0.32, 0.45]    Предсказание: False
# Входные данные [1.15, -0.01]    Предсказание: True
# Входные данные [0.36, 1.32]    Предсказание: True
# Входные данные [0.35000000000000003, 0.98]    Предсказание: True
# Входные данные [0.96, -0.44]    Предсказание: True
# Входные данные [-0.05, 1.3599999999999999]    Предсказание: True
# Входные данные [-0.41000000000000003, 1.03]    Предсказание: True
# Входные данные [1.4100000000000001, 1.35]    Предсказание: False
# Входные данные [1.3900000000000001, 0.21]    Предсказание: True
# Входные данные [-0.26, 0.6799999999999999]    Предсказание: True
# Входные данные [0.04, 0.97]    Предсказание: True
# Входные данные [0.95, 0.23]    Предсказание: True
# Входные данные [0.03, 0.41000000000000003]    Предсказание: False
# Входные данные [-0.35000000000000003, 0.62]    Предсказание: True
# Входные данные [0.01, 1.29]    Предсказание: True
# Входные данные [-0.03, 0.11]    Предсказание: False
# Входные данные [0.24, 0.8]    Предсказание: True
# Входные данные [0.07, 0.5800000000000001]    Предсказание: True
# Входные данные [1.16, 0.33]    Предсказание: True
# Входные данные [1.37, 1.01]    Предсказание: False
# Входные данные [0.41000000000000003, -0.42]    Предсказание: False
# Входные данные [1.1400000000000001, 1.17]    Предсказание: False
# Входные данные [1.44, 0.19]    Предсказание: True
# Входные данные [0.0, -0.19]    Предсказание: False
# Входные данные [0.35000000000000003, 1.35]    Предсказание: True
# Входные данные [-0.32, 0.02]    Предсказание: False
# Входные данные [-0.18, -0.43]    Предсказание: False
# Входные данные [0.34, 1.43]    Предсказание: True
# Входные данные [0.86, -0.21]    Предсказание: True
# Входные данные [-0.35000000000000003, -0.18]    Предсказание: False
# Входные данные [0.56, 0.63]    Предсказание: False
# Входные данные [0.35000000000000003, 0.6499999999999999]    Предсказание: True
# Входные данные [0.04, 0.04]    Предсказание: False
# Входные данные [-0.11, -0.01]    Предсказание: False
# Входные данные [-0.11, 0.39]    Предсказание: False
# Входные данные [1.01, 1.23]    Предсказание: False
# Входные данные [0.61, 0.56]    Предсказание: False
# Входные данные [1.44, -0.19]    Предсказание: True
# Входные данные [0.28, 0.37]    Предсказание: False
# Входные данные [1.29, 0.75]    Предсказание: False
# Входные данные [0.42, -0.01]    Предсказание: False
# Входные данные [1.25, 0.79]    Предсказание: False
# Входные данные [1.13, 0.94]    Предсказание: False
# Входные данные [-0.27, 1.16]    Предсказание: True
# Входные данные [-0.36, 1.11]    Предсказание: True
# Входные данные [1.34, 1.01]    Предсказание: False
# Входные данные [0.61, 1.03]    Предсказание: False
# Входные данные [-0.06, 1.01]    Предсказание: True
# Входные данные [0.43, 1.1400000000000001]    Предсказание: True
# Входные данные [1.3, 0.19]    Предсказание: True
# Входные данные [-0.03, 1.4]    Предсказание: True
# Входные данные [0.89, -0.15]    Предсказание: True
# Входные данные [0.6599999999999999, 1.19]    Предсказание: False
# Входные данные [1.16, 0.1]    Предсказание: True
# Входные данные [1.22, -0.41000000000000003]    Предсказание: True
# Входные данные [1.19, -0.11]    Предсказание: True
# Входные данные [-0.1, 0.12]    Предсказание: False
# Входные данные [-0.24, 0.35000000000000003]    Предсказание: False
# Входные данные [-0.12, 1.29]    Предсказание: True
# Входные данные [0.23, 0.12]    Предсказание: False
# Входные данные [1.15, 1.06]    Предсказание: False
# Входные данные [0.81, -0.18]    Предсказание: True
# Входные данные [-0.41000000000000003, -0.16]    Предсказание: False
# Входные данные [-0.42, 1.1400000000000001]    Предсказание: True
# Входные данные [1.35, -0.01]    Предсказание: True
# Входные данные [-0.04, 0.2]    Предсказание: False
# Входные данные [1.28, 1.19]    Предсказание: False
# Входные данные [0.9, -0.15]    Предсказание: True
# Входные данные [-0.39, -0.17]    Предсказание: False
# Входные данные [0.85, 0.19]    Предсказание: True
# Входные данные [1.32, 1.31]    Предсказание: False
# Входные данные [0.16, 0.8200000000000001]    Предсказание: True
# Входные данные [1.11, 0.9]    Предсказание: False
# Входные данные [0.98, 0.5800000000000001]    Предсказание: False
# Входные данные [0.22, -0.09]    Предсказание: False
# Входные данные [0.38, 1.27]    Предсказание: True
# Входные данные [0.2, 0.7]    Предсказание: True
# Входные данные [1.05, 1.31]    Предсказание: False
# Входные данные [-0.15, -0.36]    Предсказание: False
# Входные данные [0.55, 0.26]    Предсказание: True
# Входные данные [0.41000000000000003, 0.9]    Предсказание: True
# Входные данные [0.2, -0.2]    Предсказание: False
# Входные данные [1.31, -0.06]    Предсказание: True
# Входные данные [0.24, -0.15]    Предсказание: False
# Входные данные [0.31, 0.07]    Предсказание: False
# Входные данные [0.24, 1.07]    Предсказание: True
# Входные данные [0.75, 0.1]    Предсказание: True
# Входные данные [-0.05, 0.94]    Предсказание: True
# Входные данные [1.33, 0.97]    Предсказание: False
# Входные данные [1.21, -0.19]    Предсказание: True
# Входные данные [1.1400000000000001, 0.6]    Предсказание: False
# Входные данные [1.07, -0.26]    Предсказание: True
# Входные данные [0.63, -0.4]    Предсказание: True
# Входные данные [0.03, 0.0]    Предсказание: False
# Входные данные [-0.22, 0.39]    Предсказание: False
# Входные данные [1.18, -0.37]    Предсказание: True
# Входные данные [0.69, 1.12]    Предсказание: False
# Входные данные [0.39, -0.09]    Предсказание: False
# Входные данные [1.12, -0.37]    Предсказание: True
# Входные данные [0.59, -0.14]    Предсказание: True
# Входные данные [-0.45, 0.4]    Предсказание: False
# Входные данные [-0.28, 1.25]    Предсказание: True
# Входные данные [0.28, 1.43]    Предсказание: True
# Входные данные [1.2, -0.4]    Предсказание: True
# Входные данные [0.72, 0.31]    Предсказание: True
# Входные данные [0.94, -0.09]    Предсказание: True
# Входные данные [-0.05, 0.8200000000000001]    Предсказание: True
# Входные данные [0.33, 0.72]    Предсказание: True
# Входные данные [0.07, -0.2]    Предсказание: False
# Входные данные [0.69, 0.38]    Предсказание: True
# Входные данные [-0.4, 0.59]    Предсказание: True
# Входные данные [-0.38, 1.16]    Предсказание: True
# Входные данные [0.18, 1.44]    Предсказание: True
# Входные данные [0.02, 1.03]    Предсказание: True
# Входные данные [1.08, 1.19]    Предсказание: False
# Входные данные [0.64, 0.14]    Предсказание: True
# Входные данные [0.6699999999999999, 0.14]    Предсказание: True
# Входные данные [-0.14, 0.6]    Предсказание: True
# Входные данные [0.7, -0.38]    Предсказание: True
# Входные данные [-0.1, 1.42]    Предсказание: True
# Входные данные [0.56, 0.6599999999999999]    Предсказание: False
# Входные данные [-0.12, 0.9]    Предсказание: True
# Входные данные [0.6599999999999999, 0.9]    Предсказание: False
# Входные данные [0.04, 0.1]    Предсказание: False
# Входные данные [-0.3, 0.22]    Предсказание: False
# Входные данные [0.33, 0.3]    Предсказание: False
# Входные данные [0.25, 0.8200000000000001]    Предсказание: True
# Входные данные [1.1, 1.33]    Предсказание: False
# Входные данные [1.25, -0.19]    Предсказание: True
# Входные данные [0.76, 1.0]    Предсказание: False
# Входные данные [0.09, 0.14]    Предсказание: False
# Входные данные [0.37, 1.01]    Предсказание: True
# Входные данные [0.84, 1.3900000000000001]    Предсказание: False
# Входные данные [1.04, 0.3]    Предсказание: True
# Входные данные [1.13, 0.84]    Предсказание: False
# Входные данные [0.94, 0.55]    Предсказание: False
# Входные данные [1.3, -0.34]    Предсказание: True
# Входные данные [1.43, 0.2]    Предсказание: True
# Входные данные [-0.4, 0.71]    Предсказание: True
# Входные данные [0.77, 0.83]    Предсказание: False
# Входные данные [-0.12, 1.1]    Предсказание: True
# Входные данные [0.13, 0.05]    Предсказание: False
# Входные данные [0.73, 1.28]    Предсказание: False
# Входные данные [-0.22, 0.4]    Предсказание: False
# Входные данные [0.9, 1.13]    Предсказание: False
# Входные данные [0.29, -0.01]    Предсказание: False
# Входные данные [-0.09, 1.42]    Предсказание: True
# Входные данные [1.1400000000000001, 1.25]    Предсказание: False
# Входные данные [1.34, 0.25]    Предсказание: True
# Входные данные [1.3, 1.01]    Предсказание: False
# Входные данные [0.4, 0.61]    Предсказание: True
# Входные данные [0.81, -0.12]    Предсказание: True
# Входные данные [0.14, 0.24]    Предсказание: False
# Входные данные [0.72, 1.03]    Предсказание: False
# Входные данные [-0.43, 1.24]    Предсказание: True
# Входные данные [0.74, 0.25]    Предсказание: True
# Входные данные [1.09, 0.0]    Предсказание: True
# Входные данные [1.24, 0.91]    Предсказание: False
# Входные данные [0.39, 0.6799999999999999]    Предсказание: True
# Входные данные [0.06, 0.94]    Предсказание: True
# Входные данные [0.4, 1.3599999999999999]    Предсказание: True
# Входные данные [-0.36, 1.03]    Предсказание: True
# Входные данные [0.8200000000000001, 0.92]    Предсказание: False
# Входные данные [0.24, 0.6599999999999999]    Предсказание: True
# Входные данные [0.92, 1.31]    Предсказание: False
# Входные данные [0.6799999999999999, 1.1400000000000001]    Предсказание: False
# Входные данные [0.18, 0.5700000000000001]    Предсказание: True
# Входные данные [-0.16, 0.87]    Предсказание: True
# Входные данные [-0.42, 0.08]    Предсказание: False
# Входные данные [-0.04, -0.41000000000000003]    Предсказание: False
# Входные данные [-0.06, 0.94]    Предсказание: True
# Входные данные [1.44, 0.7]    Предсказание: False
# Входные данные [-0.1, 0.17]    Предсказание: False
# Входные данные [0.01, 0.75]    Предсказание: True
# Входные данные [0.16, 0.88]    Предсказание: True
# Входные данные [0.43, 0.79]    Предсказание: True
# Входные данные [0.02, -0.44]    Предсказание: False
# Входные данные [1.3, 0.27]    Предсказание: True
# Входные данные [0.14, -0.11]    Предсказание: False
# Входные данные [1.33, 1.32]    Предсказание: False
# Входные данные [0.24, 0.9]    Предсказание: True
# Входные данные [0.23, 1.21]    Предсказание: True
# Входные данные [1.34, 1.31]    Предсказание: False
# Входные данные [-0.23, -0.44]    Предсказание: False
# Входные данные [0.28, 0.6799999999999999]    Предсказание: True
# Входные данные [-0.01, 0.37]    Предсказание: False
# Входные данные [0.18, 1.02]    Предсказание: True
# Входные данные [0.6799999999999999, 0.11]    Предсказание: True
# Входные данные [0.79, 0.16]    Предсказание: True
# Входные данные [0.69, -0.14]    Предсказание: True
# Входные данные [0.29, -0.42]    Предсказание: False
# Входные данные [0.26, -0.15]    Предсказание: False
# Входные данные [1.37, 0.81]    Предсказание: False
# Входные данные [0.09, -0.18]    Предсказание: False
# Входные данные [-0.3, 0.2]    Предсказание: False
# Входные данные [-0.1, 1.32]    Предсказание: True
# Входные данные [0.19, 1.06]    Предсказание: True
# Входные данные [0.33, 0.36]    Предсказание: False
# Входные данные [0.75, 0.31]    Предсказание: True
# Входные данные [1.27, -0.11]    Предсказание: True
# Входные данные [1.06, 1.31]    Предсказание: False
# Входные данные [0.61, -0.07]    Предсказание: True
# Входные данные [1.06, 1.18]    Предсказание: False
# Входные данные [0.43, -0.3]    Предсказание: False
# Входные данные [0.33, 1.35]    Предсказание: True
# Входные данные [0.41000000000000003, 1.17]    Предсказание: True
# Входные данные [-0.44, 1.04]    Предсказание: True
# Входные данные [-0.05, 0.09]    Предсказание: False
# Входные данные [-0.25, 0.18]    Предсказание: False
# Входные данные [1.37, 0.61]    Предсказание: False
# Входные данные [-0.38, 1.27]    Предсказание: True
# Входные данные [0.76, 0.27]    Предсказание: True
# Входные данные [0.73, 0.76]    Предсказание: False
# Входные данные [1.12, 0.6799999999999999]    Предсказание: False
# Входные данные [-0.26, 0.84]    Предсказание: True
# Входные данные [0.1, -0.44]    Предсказание: False
# Входные данные [1.23, 0.27]    Предсказание: True
# Входные данные [0.78, 0.29]    Предсказание: True
# Входные данные [0.06, 1.28]    Предсказание: True
# Входные данные [0.02, 1.16]    Предсказание: True
# Входные данные [-0.31, 0.41000000000000003]    Предсказание: False
# Входные данные [-0.22, 0.89]    Предсказание: True
# Входные данные [0.35000000000000003, -0.38]    Предсказание: False
# Входные данные [0.23, 0.13]    Предсказание: False
# Входные данные [0.4, -0.03]    Предсказание: False
# Входные данные [1.08, 0.01]    Предсказание: True
# Входные данные [1.17, 0.37]    Предсказание: True
# Входные данные [0.89, 0.31]    Предсказание: True
# Входные данные [0.78, 0.6699999999999999]    Предсказание: False
# Входные данные [0.11, -0.26]    Предсказание: False
# Входные данные [-0.35000000000000003, 1.31]    Предсказание: True
# Входные данные [0.72, 1.22]    Предсказание: False
# Входные данные [0.37, 0.16]    Предсказание: False
# Входные данные [-0.06, 0.59]    Предсказание: True
# Входные данные [1.33, 0.05]    Предсказание: True
# Входные данные [0.8200000000000001, 0.25]    Предсказание: True
# Входные данные [0.78, 0.83]    Предсказание: False
# Входные данные [0.04, 0.75]    Предсказание: True
# Входные данные [0.32, 1.06]    Предсказание: True
# Входные данные [-0.3, 1.24]    Предсказание: True
# Входные данные [0.96, 0.1]    Предсказание: True
# Входные данные [0.03, 0.61]    Предсказание: True
# Входные данные [0.42, -0.23]    Предсказание: False
# Входные данные [0.69, -0.44]    Предсказание: True
# Входные данные [0.15, 0.07]    Предсказание: False
# Входные данные [0.06, 0.21]    Предсказание: False
# Входные данные [1.42, 0.33]    Предсказание: True
# Входные данные [0.32, -0.15]    Предсказание: False
# Входные данные [-0.41000000000000003, 0.79]    Предсказание: True
# Входные данные [1.38, -0.36]    Предсказание: True
# Входные данные [0.34, 1.16]    Предсказание: True
# Входные данные [1.28, -0.25]    Предсказание: True
# Входные данные [0.71, 0.6699999999999999]    Предсказание: False
# Входные данные [0.91, 1.07]    Предсказание: False
# Входные данные [-0.4, 0.55]    Предсказание: True
# Входные данные [-0.17, -0.17]    Предсказание: False
# Входные данные [0.38, -0.32]    Предсказание: False
# Входные данные [0.8, 0.38]    Предсказание: True
# Входные данные [1.03, 0.91]    Предсказание: False
# Входные данные [0.31, 1.45]    Предсказание: True
# Входные данные [-0.03, -0.16]    Предсказание: False
# Входные данные [0.96, 0.41000000000000003]    Предсказание: True
# Входные данные [0.81, -0.21]    Предсказание: True
# Входные данные [-0.33, -0.06]    Предсказание: False
# Входные данные [0.85, 0.77]    Предсказание: False
# Входные данные [1.45, 0.19]    Предсказание: True
# Входные данные [-0.26, 1.27]    Предсказание: True
# Входные данные [-0.45, 1.3900000000000001]    Предсказание: True
# Входные данные [-0.13, -0.14]    Предсказание: False
# Входные данные [-0.12, 1.1400000000000001]    Предсказание: True
# Входные данные [0.24, 0.77]    Предсказание: True
# Входные данные [0.18, 0.8]    Предсказание: True
# Входные данные [0.07, 0.6]    Предсказание: True
# Входные данные [0.63, 0.7]    Предсказание: False
# Входные данные [0.83, 0.79]    Предсказание: False
# Входные данные [0.33, 0.95]    Предсказание: True
# Входные данные [-0.16, 0.09]    Предсказание: False
# Входные данные [-0.19, 1.21]    Предсказание: True
# Входные данные [0.94, 1.13]    Предсказание: False
# Входные данные [0.3, -0.28]    Предсказание: False
# Входные данные [-0.25, 0.4]    Предсказание: False
# Входные данные [1.02, 0.6499999999999999]    Предсказание: False
# Входные данные [1.17, 0.6]    Предсказание: False
# Входные данные [-0.19, 1.27]    Предсказание: True
# Входные данные [-0.38, 0.87]    Предсказание: True
# Входные данные [1.42, 1.38]    Предсказание: False
# Входные данные [-0.18, 1.06]    Предсказание: True
# Входные данные [0.07, -0.03]    Предсказание: False
# Входные данные [0.97, 1.25]    Предсказание: False
# Входные данные [0.55, 0.83]    Предсказание: False
# Входные данные [0.87, 0.2]    Предсказание: True
# Входные данные [0.04, -0.36]    Предсказание: False
# Входные данные [0.56, 0.7]    Предсказание: False
# Входные данные [-0.22, -0.1]    Предсказание: False
# Входные данные [-0.35000000000000003, -0.12]    Предсказание: False
# Входные данные [0.77, 1.3599999999999999]    Предсказание: False
# Входные данные [1.18, -0.11]    Предсказание: True
# Входные данные [0.9299999999999999, 0.07]    Предсказание: True
# Входные данные [0.18, 0.4]    Предсказание: False
# Входные данные [0.19, 1.37]    Предсказание: True
# Входные данные [-0.12, 1.13]    Предсказание: True
# Входные данные [-0.34, 0.89]    Предсказание: True
# Входные данные [0.08, 0.99]    Предсказание: True
# Входные данные [1.11, 0.3]    Предсказание: True
# Входные данные [1.19, 1.4100000000000001]    Предсказание: False
# Входные данные [0.85, 1.4100000000000001]    Предсказание: False
# Входные данные [0.63, 0.22]    Предсказание: True
# Входные данные [0.69, 1.16]    Предсказание: False
# Входные данные [-0.09, 0.41000000000000003]    Предсказание: False
# Входные данные [0.62, 0.23]    Предсказание: True
# Входные данные [0.6, 1.34]    Предсказание: False
# Входные данные [0.1, 1.3900000000000001]    Предсказание: True
# Входные данные [0.21, 0.88]    Предсказание: True
# Входные данные [1.24, 0.97]    Предсказание: False
# Входные данные [0.16, 1.44]    Предсказание: True
# Входные данные [0.19, 1.23]    Предсказание: True
# Входные данные [0.45, -0.06]    Предсказание: False
# Входные данные [-0.18, -0.42]    Предсказание: False
# Входные данные [1.11, -0.29]    Предсказание: True
# Входные данные [0.25, 0.15]    Предсказание: False
# Входные данные [1.37, 0.04]    Предсказание: True
# Входные данные [0.03, -0.4]    Предсказание: False
# Входные данные [-0.29, 0.63]    Предсказание: True
# Входные данные [-0.32, 1.33]    Предсказание: True
# Входные данные [1.01, 0.43]    Предсказание: True
# Входные данные [0.29, 0.91]    Предсказание: True
# Входные данные [0.71, 0.89]    Предсказание: False
# Входные данные [0.04, -0.05]    Предсказание: False
# Входные данные [-0.24, -0.09]    Предсказание: False
# Входные данные [1.32, 0.26]    Предсказание: True
# Входные данные [1.24, 0.63]    Предсказание: False
# Входные данные [0.56, -0.41000000000000003]    Предсказание: True
# Входные данные [1.23, 0.73]    Предсказание: False
# Входные данные [0.39, 1.0]    Предсказание: True
# Входные данные [0.61, -0.31]    Предсказание: True
# Входные данные [-0.43, -0.08]    Предсказание: False
# Входные данные [-0.41000000000000003, 0.69]    Предсказание: True
# Входные данные [1.22, 0.6499999999999999]    Предсказание: False
# Входные данные [1.43, 0.32]    Предсказание: True
# Входные данные [1.32, 0.71]    Предсказание: False
# Входные данные [0.44, 0.35000000000000003]    Предсказание: False
# Входные данные [0.73, 0.89]    Предсказание: False
# Входные данные [1.02, -0.36]    Предсказание: True
# Входные данные [0.23, -0.08]    Предсказание: False
# Входные данные [1.4100000000000001, -0.16]    Предсказание: True
# Входные данные [-0.26, 1.3]    Предсказание: True
# Входные данные [0.44, 1.29]    Предсказание: True
# Входные данные [-0.34, 1.12]    Предсказание: True
# Входные данные [0.97, 0.61]    Предсказание: False
# Входные данные [-0.04, -0.12]    Предсказание: False
# Входные данные [0.83, 0.6699999999999999]    Предсказание: False
# Входные данные [-0.42, 0.64]    Предсказание: True
# Входные данные [0.39, -0.34]    Предсказание: False
# Входные данные [1.1, 0.43]    Предсказание: True
# Входные данные [1.29, -0.45]    Предсказание: True
# Входные данные [-0.3, -0.04]    Предсказание: False
# Входные данные [-0.24, -0.29]    Предсказание: False
# Входные данные [-0.22, 0.94]    Предсказание: True
# Входные данные [0.73, 1.24]    Предсказание: False
# Входные данные [0.89, 0.03]    Предсказание: True
# Входные данные [0.79, 1.42]    Предсказание: False
# Входные данные [-0.19, -0.04]    Предсказание: False
# Входные данные [0.6799999999999999, 0.02]    Предсказание: True
# Входные данные [0.8, 0.27]    Предсказание: True
# Входные данные [0.45, -0.31]    Предсказание: False
# Входные данные [-0.04, -0.14]    Предсказание: False
# Входные данные [-0.39, -0.14]    Предсказание: False
# Входные данные [0.6799999999999999, 0.98]    Предсказание: False
# Входные данные [-0.13, 0.84]    Предсказание: True
# Входные данные [0.72, 0.37]    Предсказание: True
# Входные данные [0.18, 0.75]    Предсказание: True
# Входные данные [0.78, 1.27]    Предсказание: False
# Входные данные [-0.39, 0.6599999999999999]    Предсказание: True
# Входные данные [1.3, 0.01]    Предсказание: True
# Входные данные [1.34, 0.72]    Предсказание: False
# Входные данные [-0.1, 0.81]    Предсказание: True
# Входные данные [1.01, 1.17]    Предсказание: False
# Входные данные [0.5700000000000001, 1.04]    Предсказание: False
# Входные данные [-0.36, -0.45]    Предсказание: False
# Входные данные [0.75, 0.25]    Предсказание: True
# Входные данные [-0.15, 0.45]    Предсказание: False
# Входные данные [-0.44, 0.4]    Предсказание: False
# Входные данные [-0.12, 0.44]    Предсказание: False
# Входные данные [0.87, 0.1]    Предсказание: True
# Входные данные [0.21, 0.95]    Предсказание: True
# Входные данные [1.3, 0.34]    Предсказание: True
# Входные данные [1.03, 0.64]    Предсказание: False
# Входные данные [-0.23, 1.42]    Предсказание: True
# Входные данные [1.13, 1.4100000000000001]    Предсказание: False
# Входные данные [1.18, -0.09]    Предсказание: True
# Входные данные [1.35, -0.36]    Предсказание: True
# Входные данные [0.34, 0.89]    Предсказание: True
# Входные данные [1.28, 1.25]    Предсказание: False
# Входные данные [0.35000000000000003, 1.23]    Предсказание: True
# Входные данные [0.26, 1.32]    Предсказание: True
# Входные данные [0.0, 0.07]    Предсказание: False
# Входные данные [0.19, 0.64]    Предсказание: True
# Входные данные [0.3, 0.79]    Предсказание: True
# Входные данные [-0.19, 0.99]    Предсказание: True
# Входные данные [-0.43, 1.19]    Предсказание: True
# Входные данные [0.73, 1.24]    Предсказание: False
# Входные данные [0.6599999999999999, -0.28]    Предсказание: True
# Входные данные [0.6799999999999999, -0.09]    Предсказание: True
# Входные данные [1.18, -0.16]    Предсказание: True
# Входные данные [-0.03, 0.37]    Предсказание: False
# Входные данные [-0.16, 1.43]    Предсказание: True
# Входные данные [-0.27, 0.71]    Предсказание: True
# Входные данные [0.4, 0.29]    Предсказание: False
# Входные данные [0.35000000000000003, 0.39]    Предсказание: False
# Входные данные [1.12, 0.18]    Предсказание: True
# Входные данные [0.64, 0.92]    Предсказание: False
# Входные данные [0.41000000000000003, 0.7]    Предсказание: True
# Входные данные [0.8, -0.12]    Предсказание: True
# Входные данные [0.05, -0.03]    Предсказание: False
# Входные данные [0.18, 0.44]    Предсказание: False
# Входные данные [1.32, -0.09]    Предсказание: True
# Входные данные [-0.43, 1.11]    Предсказание: True
# Входные данные [0.56, 0.5800000000000001]    Предсказание: False
# Входные данные [0.6699999999999999, 1.1]    Предсказание: False
# Входные данные [0.59, 0.43]    Предсказание: True
# Входные данные [0.34, 0.9]    Предсказание: True
# Входные данные [0.99, 0.03]    Предсказание: True
# Входные данные [0.23, 1.4100000000000001]    Предсказание: True
# Входные данные [0.71, 0.0]    Предсказание: True
# Входные данные [1.08, 0.0]    Предсказание: True
# Входные данные [1.35, 0.77]    Предсказание: False
# Входные данные [0.98, 0.26]    Предсказание: True
# Входные данные [0.15, 0.61]    Предсказание: True
# Входные данные [1.34, -0.45]    Предсказание: True
# Входные данные [1.07, 0.05]    Предсказание: True
# Входные данные [0.8, -0.34]    Предсказание: True
# Входные данные [0.86, -0.11]    Предсказание: True
# Входные данные [0.61, 1.35]    Предсказание: False
# Входные данные [0.13, 0.13]    Предсказание: False
# Входные данные [0.96, 0.99]    Предсказание: False
# Входные данные [0.81, 0.94]    Предсказание: False
# Входные данные [1.19, 0.96]    Предсказание: False
# Входные данные [0.62, 0.24]    Предсказание: True
# Входные данные [1.17, 1.22]    Предсказание: False
# Входные данные [-0.08, 0.5700000000000001]    Предсказание: True
# Входные данные [-0.16, 0.6599999999999999]    Предсказание: True
# Входные данные [-0.25, 0.23]    Предсказание: False
# Входные данные [1.4, 1.1]    Предсказание: False
# Входные данные [-0.34, 0.4]    Предсказание: False
# Входные данные [0.02, -0.13]    Предсказание: False
# Входные данные [0.63, -0.42]    Предсказание: True
# Входные данные [0.69, 0.1]    Предсказание: True
# Входные данные [1.03, -0.02]    Предсказание: True
# Входные данные [0.94, 0.7]    Предсказание: False
# Входные данные [-0.09, 0.84]    Предсказание: True
# Входные данные [0.6799999999999999, 0.87]    Предсказание: False
# Входные данные [0.8200000000000001, 1.06]    Предсказание: False
# Входные данные [1.02, 0.61]    Предсказание: False
# Входные данные [1.17, 0.87]    Предсказание: False
# Входные данные [-0.29, -0.28]    Предсказание: False
# Входные данные [0.28, 0.39]    Предсказание: False
# Входные данные [0.31, 1.33]    Предсказание: True
# Входные данные [0.96, 1.12]    Предсказание: False
# Входные данные [0.83, -0.24]    Предсказание: True
# Входные данные [0.62, 0.73]    Предсказание: False
# Входные данные [0.78, 0.16]    Предсказание: True
# Входные данные [0.42, -0.02]    Предсказание: False
# Входные данные [0.2, -0.09]    Предсказание: False
# Входные данные [0.59, -0.07]    Предсказание: True
# Входные данные [0.77, 1.15]    Предсказание: False
# Входные данные [1.13, 0.6499999999999999]    Предсказание: False
# Входные данные [0.21, 1.43]    Предсказание: True
# Входные данные [0.12, 0.19]    Предсказание: False
# Входные данные [0.92, 0.77]    Предсказание: False
# Входные данные [0.7, 1.24]    Предсказание: False
# Входные данные [1.4100000000000001, 0.28]    Предсказание: True
# Входные данные [-0.24, 1.3599999999999999]    Предсказание: True
# Входные данные [0.3, 0.43]    Предсказание: False
# Входные данные [0.24, 0.6599999999999999]    Предсказание: True
# Входные данные [0.22, 0.78]    Предсказание: True
# Входные данные [0.2, 0.01]    Предсказание: False
# Входные данные [-0.34, 0.39]    Предсказание: False
# Входные данные [0.35000000000000003, 0.43]    Предсказание: False
# Входные данные [1.26, 1.15]    Предсказание: False
# Входные данные [1.19, -0.26]    Предсказание: True
# Входные данные [-0.32, 1.38]    Предсказание: True
# Входные данные [1.15, -0.42]    Предсказание: True
# Входные данные [1.1400000000000001, 0.6499999999999999]    Предсказание: False
# Входные данные [-0.27, 1.24]    Предсказание: True
# Входные данные [1.38, -0.2]    Предсказание: True
# Входные данные [1.05, 1.2]    Предсказание: False
# Входные данные [0.62, 0.64]    Предсказание: False
# Входные данные [1.11, 1.08]    Предсказание: False
# Входные данные [-0.23, 1.05]    Предсказание: True
# Входные данные [-0.25, 0.98]    Предсказание: True
# Входные данные [0.04, 1.31]    Предсказание: True
# Входные данные [1.19, 0.2]    Предсказание: True
# Входные данные [0.9299999999999999, 0.17]    Предсказание: True
# Входные данные [0.31, 1.1400000000000001]    Предсказание: True
# Входные данные [-0.19, 1.23]    Предсказание: True
# Входные данные [1.13, 0.5700000000000001]    Предсказание: False
# Входные данные [0.42, -0.3]    Предсказание: False
# Входные данные [0.04, -0.32]    Предсказание: False
# Входные данные [0.88, 0.19]    Предсказание: True
# Входные данные [-0.2, 0.61]    Предсказание: True
# Входные данные [0.63, 0.75]    Предсказание: False
# Входные данные [-0.43, 1.09]    Предсказание: True
# Входные данные [-0.41000000000000003, 0.03]    Предсказание: False
# Входные данные [-0.16, 0.39]    Предсказание: False
# Входные данные [-0.29, 1.15]    Предсказание: True
# Входные данные [0.71, 0.79]    Предсказание: False
# Входные данные [0.5800000000000001, -0.2]    Предсказание: True
# Входные данные [0.64, 1.24]    Предсказание: False
# Входные данные [1.01, -0.27]    Предсказание: True
# Входные данные [1.11, 0.04]    Предсказание: True
# Входные данные [0.34, 0.75]    Предсказание: True
# Входные данные [0.38, 0.03]    Предсказание: False
# Входные данные [0.86, 0.94]    Предсказание: False
# Входные данные [0.18, 0.61]    Предсказание: True
# Входные данные [-0.23, 1.18]    Предсказание: True
# Входные данные [0.34, 1.29]    Предсказание: True
# Входные данные [0.17, 0.33]    Предсказание: False
# Входные данные [-0.4, 1.37]    Предсказание: True
# Входные данные [0.02, -0.29]    Предсказание: False
# Входные данные [0.34, 1.27]    Предсказание: True
# Входные данные [1.01, 1.31]    Предсказание: False
# Входные данные [1.3, 0.56]    Предсказание: False
# Входные данные [0.3, 0.05]    Предсказание: False
# Входные данные [0.62, -0.28]    Предсказание: True
# Входные данные [0.78, 1.16]    Предсказание: False
# Входные данные [0.6499999999999999, 0.21]    Предсказание: True
# Входные данные [0.24, 0.14]    Предсказание: False
# Входные данные [0.62, -0.08]    Предсказание: True
# Входные данные [0.4, 0.43]    Предсказание: False
# Входные данные [0.01, 1.28]    Предсказание: True
# Входные данные [0.9, 1.17]    Предсказание: False
# Входные данные [0.19, -0.33]    Предсказание: False
# Входные данные [0.95, 1.08]    Предсказание: False
# Входные данные [1.21, 0.69]    Предсказание: False
# Входные данные [1.32, 0.61]    Предсказание: False
# Входные данные [0.1, -0.45]    Предсказание: False
# Входные данные [1.09, 0.8200000000000001]    Предсказание: False
# Входные данные [-0.39, 0.03]    Предсказание: False
# Входные данные [-0.01, -0.34]    Предсказание: False
# Входные данные [-0.06, 0.8]    Предсказание: True
# Входные данные [0.09, 0.45]    Предсказание: False
# Входные данные [1.43, 0.8200000000000001]    Предсказание: False
# Входные данные [0.32, 0.7]    Предсказание: True
# Входные данные [-0.19, 0.73]    Предсказание: True
# Входные данные [0.43, -0.2]    Предсказание: False
# Входные данные [1.19, 0.34]    Предсказание: True
# Входные данные [1.16, -0.42]    Предсказание: True
# Входные данные [-0.44, 1.11]    Предсказание: True
# Входные данные [1.1, -0.43]    Предсказание: True
# Входные данные [0.5800000000000001, 1.33]    Предсказание: False
# Входные данные [0.89, 1.07]    Предсказание: False
# Входные данные [0.84, -0.09]    Предсказание: True
# Входные данные [0.94, -0.11]    Предсказание: True
# Входные данные [0.29, 0.45]    Предсказание: False
# Входные данные [1.05, 1.34]    Предсказание: False
# Входные данные [0.59, 0.74]    Предсказание: False
# Входные данные [-0.12, 0.05]    Предсказание: False
# Входные данные [0.8, 0.33]    Предсказание: True
# Входные данные [1.06, 1.37]    Предсказание: False
# Входные данные [0.95, 0.83]    Предсказание: False
# Входные данные [0.05, -0.11]    Предсказание: False
# Входные данные [0.81, 0.59]    Предсказание: False
# Входные данные [0.02, -0.3]    Предсказание: False
# Входные данные [-0.23, 0.64]    Предсказание: True
# Входные данные [-0.01, -0.39]    Предсказание: False
# Входные данные [0.59, 0.44]    Предсказание: True
# Входные данные [-0.13, 0.35000000000000003]    Предсказание: False
# Входные данные [1.06, 0.6499999999999999]    Предсказание: False
# Входные данные [-0.19, 1.25]    Предсказание: True
# Входные данные [1.45, 0.6]    Предсказание: False
# Входные данные [0.44, 0.23]    Предсказание: False
# Входные данные [1.4100000000000001, 0.09]    Предсказание: True
# Входные данные [1.1, 0.62]    Предсказание: False
# Входные данные [1.02, 0.0]    Предсказание: True
# Входные данные [1.29, 0.8200000000000001]    Предсказание: False
# Входные данные [0.84, 0.6]    Предсказание: False
# Входные данные [-0.37, 0.0]    Предсказание: False
# Входные данные [0.21, 0.44]    Предсказание: False
# Входные данные [0.24, -0.09]    Предсказание: False
# Входные данные [1.34, 1.37]    Предсказание: False
# Входные данные [0.97, 1.21]    Предсказание: False
# Входные данные [0.26, -0.19]    Предсказание: False
# Входные данные [0.22, 0.26]    Предсказание: False
# Входные данные [0.6, 1.33]    Предсказание: False
# Входные данные [0.56, 0.18]    Предсказание: True
# Входные данные [-0.36, 1.1]    Предсказание: True
# Входные данные [0.33, 0.29]    Предсказание: False
# Входные данные [0.45, 0.91]    Предсказание: True
# Входные данные [0.63, -0.11]    Предсказание: True
# Входные данные [1.1400000000000001, -0.23]    Предсказание: True
# Входные данные [1.01, 1.1400000000000001]    Предсказание: False
# Входные данные [0.1, 0.04]    Предсказание: False
# Входные данные [0.92, 0.02]    Предсказание: True
# Входные данные [0.86, 0.05]    Предсказание: True
# Входные данные [1.38, 0.78]    Предсказание: False
# Входные данные [0.43, -0.31]    Предсказание: False
# Входные данные [0.74, 1.44]    Предсказание: False
# Входные данные [-0.38, 0.03]    Предсказание: False
# Входные данные [-0.45, 1.28]    Предсказание: True
# Входные данные [0.15, -0.04]    Предсказание: False
# Входные данные [0.74, -0.33]    Предсказание: True
# Входные данные [0.74, -0.1]    Предсказание: True
# Входные данные [1.3, 0.81]    Предсказание: False
# Входные данные [1.3900000000000001, 1.3900000000000001]    Предсказание: False
# Входные данные [0.29, 0.34]    Предсказание: False
# Входные данные [-0.11, -0.14]    Предсказание: False
# Входные данные [0.63, -0.29]    Предсказание: True
# Входные данные [0.6, 0.89]    Предсказание: False
# Входные данные [0.91, 1.35]    Предсказание: False
# Входные данные [1.09, 0.15]    Предсказание: True
# Входные данные [1.32, 0.56]    Предсказание: False
# Входные данные [0.39, 0.7]    Предсказание: True
# Входные данные [1.18, 1.1400000000000001]    Предсказание: False
# Входные данные [0.79, 1.21]    Предсказание: False
# Входные данные [1.24, 1.35]    Предсказание: False
# Входные данные [-0.15, -0.02]    Предсказание: False
# Входные данные [-0.3, 0.86]    Предсказание: True
# Входные данные [0.0, 0.6799999999999999]    Предсказание: True
# Входные данные [0.08, 1.21]    Предсказание: True
# Входные данные [0.18, 1.34]    Предсказание: True
# Входные данные [1.45, -0.31]    Предсказание: True
# Входные данные [1.0, 0.99]    Предсказание: False
# Входные данные [0.59, 0.88]    Предсказание: False
# Входные данные [1.35, -0.14]    Предсказание: True
# Входные данные [1.23, 1.1]    Предсказание: False
# Входные данные [1.04, -0.26]    Предсказание: True
# Входные данные [0.4, 0.76]    Предсказание: True
# Входные данные [-0.34, -0.31]    Предсказание: False
# Входные данные [1.28, 0.62]    Предсказание: False
# Входные данные [1.05, 0.23]    Предсказание: True
# Входные данные [0.6, -0.42]    Предсказание: True
# Входные данные [-0.04, 0.61]    Предсказание: True
# Входные данные [-0.45, -0.36]    Предсказание: False
# Входные данные [-0.09, 1.42]    Предсказание: True
# Входные данные [0.04, 0.72]    Предсказание: True
# Входные данные [0.41000000000000003, 1.21]    Предсказание: True
# Входные данные [1.01, 0.13]    Предсказание: True
# Входные данные [0.76, 1.44]    Предсказание: False
# Входные данные [1.05, 0.42]    Предсказание: True
# Входные данные [0.6599999999999999, 0.6599999999999999]    Предсказание: False
# Входные данные [0.22, 1.45]    Предсказание: True
# Входные данные [0.22, 0.24]    Предсказание: False
# Входные данные [0.28, 1.1400000000000001]    Предсказание: True
# Входные данные [-0.07, 0.6599999999999999]    Предсказание: True
# Входные данные [0.04, -0.18]    Предсказание: False
# Входные данные [1.06, -0.15]    Предсказание: True
# Входные данные [-0.08, 0.56]    Предсказание: True
# Входные данные [1.34, 1.45]    Предсказание: False
# Входные данные [0.71, 0.62]    Предсказание: False
# Входные данные [0.06, 0.8]    Предсказание: True
# Входные данные [1.3900000000000001, 1.16]    Предсказание: False
# Входные данные [0.98, 0.64]    Предсказание: False
# Входные данные [0.15, 0.24]    Предсказание: False
# Входные данные [0.94, 0.4]    Предсказание: True
# Входные данные [0.0, 0.41000000000000003]    Предсказание: False
# Входные данные [0.25, 1.3900000000000001]    Предсказание: True
# Входные данные [0.22, 0.14]    Предсказание: False
# Входные данные [-0.13, 1.34]    Предсказание: True
# Входные данные [-0.07, -0.27]    Предсказание: False
# Входные данные [0.4, -0.05]    Предсказание: False
# Входные данные [0.6, 1.45]    Предсказание: False
# Входные данные [0.04, 1.06]    Предсказание: True
# Входные данные [0.5800000000000001, -0.29]    Предсказание: True
# Входные данные [1.33, -0.32]    Предсказание: True
# Входные данные [0.42, 1.1]    Предсказание: True
# Входные данные [0.86, 0.37]    Предсказание: True
# Входные данные [-0.43, 0.05]    Предсказание: False
# Входные данные [-0.39, 1.2]    Предсказание: True
# Входные данные [1.08, 0.9]    Предсказание: False
# Входные данные [0.55, 0.32]    Предсказание: True
# Входные данные [1.22, -0.13]    Предсказание: True
# Входные данные [1.03, 0.05]    Предсказание: True
# Входные данные [-0.2, 0.6]    Предсказание: True
# Входные данные [1.02, 1.23]    Предсказание: False
# Входные данные [0.76, 0.29]    Предсказание: True
# Входные данные [1.38, 0.29]    Предсказание: True
# Входные данные [1.3599999999999999, -0.16]    Предсказание: True
# Входные данные [-0.02, -0.03]    Предсказание: False
# Входные данные [0.24, 1.04]    Предсказание: True
# Входные данные [1.33, 0.34]    Предсказание: True
# Входные данные [-0.05, 0.6]    Предсказание: True
# Входные данные [-0.28, 1.09]    Предсказание: True
# Входные данные [0.6799999999999999, 1.23]    Предсказание: False
# Входные данные [1.16, 0.34]    Предсказание: True
# Входные данные [0.09, -0.4]    Предсказание: False
# Входные данные [-0.13, -0.3]    Предсказание: False
# Входные данные [-0.12, 1.09]    Предсказание: True
# Входные данные [0.44, 1.18]    Предсказание: True
# Входные данные [1.21, 0.38]    Предсказание: True
# Входные данные [0.99, -0.14]    Предсказание: True
# Входные данные [0.3, 1.02]    Предсказание: True
# Входные данные [1.09, 0.16]    Предсказание: True
# Входные данные [0.25, -0.32]    Предсказание: False
# Входные данные [0.69, 1.17]    Предсказание: False
# Входные данные [0.87, 0.01]    Предсказание: True
# Входные данные [0.61, 0.22]    Предсказание: True
# Входные данные [0.97, 0.6]    Предсказание: False
# Входные данные [0.78, 0.15]    Предсказание: True
# Входные данные [-0.3, 1.17]    Предсказание: True
# Входные данные [-0.23, 0.6599999999999999]    Предсказание: True
# Входные данные [0.32, 0.97]    Предсказание: True
# Входные данные [0.79, 0.23]    Предсказание: True
# Входные данные [0.81, 0.11]    Предсказание: True
# Входные данные [0.35000000000000003, 0.97]    Предсказание: True
# Входные данные [-0.17, -0.24]    Предсказание: False
# Входные данные [0.14, 0.34]    Предсказание: False
# Входные данные [1.28, 0.44]    Предсказание: True
# Входные данные [-0.38, 0.77]    Предсказание: True
# Входные данные [0.76, 1.04]    Предсказание: False
# Входные данные [-0.19, -0.42]    Предсказание: False
# Входные данные [0.62, -0.35000000000000003]    Предсказание: True
# Входные данные [1.06, -0.44]    Предсказание: True
# Входные данные [-0.13, 0.07]    Предсказание: False
# Входные данные [0.07, -0.33]    Предсказание: False
# Входные данные [0.91, -0.3]    Предсказание: True
# Входные данные [-0.41000000000000003, -0.01]    Предсказание: False
# Входные данные [-0.19, 1.24]    Предсказание: True
# Входные данные [0.69, 0.35000000000000003]    Предсказание: True
# Входные данные [1.1, 0.42]    Предсказание: True
# Входные данные [0.19, 0.14]    Предсказание: False
# Входные данные [-0.06, 0.01]    Предсказание: False
# Входные данные [0.91, 1.3599999999999999]    Предсказание: False
# Входные данные [0.14, 0.88]    Предсказание: True
# Входные данные [1.05, 0.84]    Предсказание: False
# Входные данные [1.11, 0.6499999999999999]    Предсказание: False
# Входные данные [0.24, -0.15]    Предсказание: False
# Входные данные [1.38, -0.24]    Предсказание: True
# Входные данные [0.74, 0.37]    Предсказание: True
# Входные данные [0.15, 0.64]    Предсказание: True
# Входные данные [0.97, -0.15]    Предсказание: True
# Входные данные [0.75, 1.28]    Предсказание: False
# Входные данные [1.38, -0.34]    Предсказание: True
# Входные данные [-0.11, 0.09]    Предсказание: False
# Входные данные [0.35000000000000003, 0.04]    Предсказание: False
# Входные данные [-0.15, -0.37]    Предсказание: False
# Входные данные [1.33, 0.84]    Предсказание: False
# Входные данные [0.36, 1.16]    Предсказание: True
# Входные данные [1.3, 0.6]    Предсказание: False
# Входные данные [0.14, 0.7]    Предсказание: True
# Входные данные [-0.38, 0.05]    Предсказание: False
# ...
# Входные данные [-0.05, -0.2]    Предсказание: False
# Входные данные [1.28, -0.4]    Предсказание: True
# Входные данные [0.28, -0.3]    Предсказание: False
# Входные данные [-0.06, 1.4]    Предсказание: True
# Входные данные [-0.4, -0.32]    Предсказание: False
# Входные данные [0.62, 0.79]    Предсказание: False
# Входные данные [0.05, 0.33]    Предсказание: False
# Входные данные [0.13, 0.6599999999999999]    Предсказание: True
# Входные данные [1.07, 0.7]    Предсказание: False
# Входные данные [0.6499999999999999, 1.03]    Предсказание: False
# Входные данные [0.81, -0.17]    Предсказание: True
# Входные данные [0.64, -0.04]    Предсказание: True
# Входные данные [-0.09, 0.94]    Предсказание: True
# Входные данные [1.35, 1.3599999999999999]    Предсказание: False
# Входные данные [0.83, -0.13]    Предсказание: True
# Входные данные [0.74, 0.86]    Предсказание: False
# Входные данные [0.34, 1.3]    Предсказание: True
# Входные данные [1.32, -0.07]    Предсказание: True
# Входные данные [0.33, 0.43]    Предсказание: False
# Входные данные [1.03, 0.6]    Предсказание: False
# Входные данные [0.8, 1.03]    Предсказание: False
# Входные данные [-0.08, 1.44]    Предсказание: True
# Входные данные [-0.23, -0.28]    Предсказание: False
# Входные данные [0.8200000000000001, -0.14]    Предсказание: True
# Входные данные [-0.41000000000000003, -0.07]    Предсказание: False
# Входные данные [0.78, 0.11]    Предсказание: True
# Входные данные [-0.44, -0.35000000000000003]    Предсказание: False
# Входные данные [0.88, 0.42]    Предсказание: True
# Входные данные [-0.23, 0.77]    Предсказание: True
# Входные данные [-0.34, 0.32]    Предсказание: False
# Входные данные [-0.04, -0.33]    Предсказание: False
# Входные данные [0.41000000000000003, 0.39]    Предсказание: False
# Входные данные [1.09, 0.87]    Предсказание: False
# Входные данные [0.05, -0.26]    Предсказание: False
# Входные данные [1.24, 1.28]    Предсказание: False
# Входные данные [0.94, -0.06]    Предсказание: True
# Входные данные [1.06, 0.14]    Предсказание: True
# Входные данные [0.77, 0.21]    Предсказание: True
# Входные данные [0.23, -0.31]    Предсказание: False
# Входные данные [0.09, 0.03]    Предсказание: False
# Входные данные [1.42, 0.0]    Предсказание: True
# Входные данные [0.59, 0.8]    Предсказание: False
# Входные данные [0.18, -0.45]    Предсказание: False
# Входные данные [-0.09, -0.23]    Предсказание: False
# Входные данные [-0.25, 1.4100000000000001]    Предсказание: True
# Входные данные [0.04, 0.32]    Предсказание: False
# Входные данные [0.74, 0.62]    Предсказание: False
# Входные данные [1.06, 1.19]    Предсказание: False
# Входные данные [1.37, 0.8200000000000001]    Предсказание: False
# Входные данные [-0.38, 0.29]    Предсказание: False
# Входные данные [0.99, -0.38]    Предсказание: True
# Входные данные [0.72, 0.06]    Предсказание: True
# Входные данные [0.88, 0.29]    Предсказание: True
# Входные данные [0.14, 0.19]    Предсказание: False
# Входные данные [0.9, 1.02]    Предсказание: False
# Входные данные [1.22, 0.94]    Предсказание: False
# Входные данные [0.3, 0.88]    Предсказание: True
# Входные данные [0.97, 0.38]    Предсказание: True
# Входные данные [0.12, 0.0]    Предсказание: False
# Входные данные [0.21, -0.44]    Предсказание: False
# Входные данные [0.03, -0.2]    Предсказание: False
# Входные данные [0.19, -0.09]    Предсказание: False
# Входные данные [1.42, 0.13]    Предсказание: True
# Входные данные [0.05, 1.25]    Предсказание: True
# Входные данные [-0.16, 1.45]    Предсказание: True
# Входные данные [0.01, 0.42]    Предсказание: False
# Входные данные [0.8200000000000001, -0.08]    Предсказание: True
# Входные данные [0.78, -0.03]    Предсказание: True
# Входные данные [-0.3, 0.69]    Предсказание: True
# Входные данные [0.76, 1.08]    Предсказание: False
# Входные данные [0.6599999999999999, -0.26]    Предсказание: True
# Входные данные [0.24, -0.45]    Предсказание: False
# Входные данные [-0.37, 0.72]    Предсказание: True
# Входные данные [1.18, 0.98]    Предсказание: False
# Входные данные [-0.45, -0.1]    Предсказание: False
# Входные данные [0.41000000000000003, 1.03]    Предсказание: True
# Входные данные [0.9, 1.4]    Предсказание: False
# Входные данные [-0.45, -0.3]    Предсказание: False
# Входные данные [0.86, 0.6799999999999999]    Предсказание: False
# Входные данные [0.39, 1.35]    Предсказание: True
# Входные данные [0.8200000000000001, 1.08]    Предсказание: False
# Входные данные [0.89, 0.96]    Предсказание: False
# Входные данные [1.32, -0.25]    Предсказание: True
# Входные данные [1.19, 0.38]    Предсказание: True
# Входные данные [1.4100000000000001, 0.3]    Предсказание: True
# Входные данные [1.24, 1.34]    Предсказание: False
# Входные данные [0.61, 0.79]    Предсказание: False
# Входные данные [0.2, 1.0]    Предсказание: True
# Входные данные [0.7, 0.02]    Предсказание: True
# Входные данные [0.07, 1.4]    Предсказание: True
# Входные данные [1.22, 1.3599999999999999]    Предсказание: False
# Входные данные [0.08, 0.42]    Предсказание: False
# Входные данные [0.98, 0.96]    Предсказание: False
# Входные данные [1.22, 0.91]    Предсказание: False
# Входные данные [0.87, 0.6599999999999999]    Предсказание: False
# Входные данные [1.3900000000000001, 0.24]    Предсказание: True
# Входные данные [-0.4, -0.18]    Предсказание: False
# Входные данные [1.19, 0.44]    Предсказание: True
# Входные данные [-0.16, 0.56]    Предсказание: True
# Входные данные [0.41000000000000003, 1.06]    Предсказание: True
# Входные данные [0.62, 0.32]    Предсказание: True
# Входные данные [0.12, 0.95]    Предсказание: True
# Входные данные [0.04, -0.14]    Предсказание: False
# Входные данные [0.71, 0.62]    Предсказание: False
# Входные данные [0.23, 0.1]    Предсказание: False
# Входные данные [0.9299999999999999, -0.34]    Предсказание: True
# Входные данные [0.72, 0.29]    Предсказание: True
# Входные данные [1.1400000000000001, 1.3599999999999999]    Предсказание: False
# Входные данные [0.38, 0.14]    Предсказание: False
# Входные данные [-0.14, 0.42]    Предсказание: False
# Входные данные [-0.23, 1.34]    Предсказание: True
# Входные данные [0.64, -0.43]    Предсказание: True
# Входные данные [0.34, 0.21]    Предсказание: False
# Входные данные [1.18, 0.44]    Предсказание: True
# Входные данные [1.03, 1.26]    Предсказание: False
# Входные данные [-0.3, -0.32]    Предсказание: False
# Входные данные [1.25, -0.4]    Предсказание: True
# Входные данные [0.45, 0.0]    Предсказание: False
# Входные данные [0.06, 0.22]    Предсказание: False
# Входные данные [1.38, 1.02]    Предсказание: False
# Входные данные [0.2, 0.14]    Предсказание: False
# Входные данные [0.23, 0.02]    Предсказание: False
# Входные данные [1.09, -0.11]    Предсказание: True
# Входные данные [0.75, -0.08]    Предсказание: True
# Входные данные [0.77, 0.75]    Предсказание: False
# Входные данные [0.07, 0.63]    Предсказание: True
# Входные данные [0.72, 0.34]    Предсказание: True
# Входные данные [0.78, 1.45]    Предсказание: False
# Входные данные [0.59, 0.37]    Предсказание: True
# Входные данные [-0.28, 1.21]    Предсказание: True
# Входные данные [-0.13, 1.33]    Предсказание: True
# Входные данные [1.4, 0.21]    Предсказание: True
# Входные данные [0.99, 0.98]    Предсказание: False
# Входные данные [-0.2, 0.16]    Предсказание: False
# Входные данные [-0.24, 0.35000000000000003]    Предсказание: False
# Входные данные [1.06, -0.31]    Предсказание: True
# Входные данные [1.1400000000000001, 1.3900000000000001]    Предсказание: False
# Входные данные [-0.32, 0.08]    Предсказание: False
# Входные данные [-0.1, 0.37]    Предсказание: False
# Входные данные [1.03, 1.32]    Предсказание: False
# Входные данные [0.16, 0.2]    Предсказание: False
# Входные данные [-0.07, 0.24]    Предсказание: False
# Входные данные [0.5700000000000001, 0.79]    Предсказание: False
# Входные данные [0.08, 1.11]    Предсказание: True
# Входные данные [0.38, 0.5800000000000001]    Предсказание: True
# Входные данные [0.15, 0.91]    Предсказание: True
# Входные данные [1.22, 1.06]    Предсказание: False
# Входные данные [1.16, 0.5800000000000001]    Предсказание: False
# Входные данные [-0.38, 0.19]    Предсказание: False
# Входные данные [-0.44, -0.4]    Предсказание: False
# Входные данные [0.06, 0.04]    Предсказание: False
# Входные данные [-0.11, 1.13]    Предсказание: True
# Входные данные [0.37, -0.13]    Предсказание: False
# Входные данные [0.15, 0.36]    Предсказание: False
# Входные данные [0.56, 0.81]    Предсказание: False
# Входные данные [0.28, 1.19]    Предсказание: True
# Входные данные [0.9, 0.13]    Предсказание: True
# Входные данные [1.17, 1.38]    Предсказание: False
# Входные данные [0.74, 0.94]    Предсказание: False
# Входные данные [0.6799999999999999, 1.09]    Предсказание: False
# Входные данные [0.1, 1.08]    Предсказание: True
# Входные данные [0.94, -0.21]    Предсказание: True
# Входные данные [1.0, 0.5700000000000001]    Предсказание: False
# Входные данные [0.96, 0.56]    Предсказание: False
# Входные данные [1.03, 1.38]    Предсказание: False
# Входные данные [-0.07, 0.28]    Предсказание: False
# Входные данные [0.6699999999999999, 0.63]    Предсказание: False
# Входные данные [0.08, 1.38]    Предсказание: True
# Входные данные [0.5800000000000001, 1.09]    Предсказание: False
# Входные данные [0.79, 1.3900000000000001]    Предсказание: False
# Входные данные [0.85, 0.56]    Предсказание: False
# Входные данные [-0.2, -0.08]    Предсказание: False
# Входные данные [-0.42, 1.3900000000000001]    Предсказание: True
# Входные данные [1.3, -0.21]    Предсказание: True
# Входные данные [0.02, 0.15]    Предсказание: False
# Входные данные [-0.06, -0.13]    Предсказание: False
# Входные данные [0.21, 1.11]    Предсказание: True
# Входные данные [-0.09, -0.23]    Предсказание: False
# Входные данные [0.22, 0.87]    Предсказание: True
# Входные данные [1.25, 1.42]    Предсказание: False
# Входные данные [-0.37, -0.11]    Предсказание: False
# Входные данные [0.55, -0.44]    Предсказание: True
# Входные данные [-0.15, -0.09]    Предсказание: False
# Входные данные [0.31, 0.7]    Предсказание: True
# Входные данные [0.08, -0.37]    Предсказание: False
# Входные данные [0.55, 1.2]    Предсказание: False
# Входные данные [0.38, 0.83]    Предсказание: True
# Входные данные [0.9, 0.6799999999999999]    Предсказание: False
# Входные данные [1.4, -0.05]    Предсказание: True
# Входные данные [1.1, 0.01]    Предсказание: True
# Входные данные [0.74, 0.22]    Предсказание: True
# Входные данные [1.15, 0.0]    Предсказание: True
# Входные данные [0.04, 1.43]    Предсказание: True
# Входные данные [1.18, 0.25]    Предсказание: True
# Входные данные [1.19, 1.31]    Предсказание: False
# Входные данные [0.69, 0.91]    Предсказание: False
# Входные данные [0.32, 0.95]    Предсказание: True
# Входные данные [0.83, 0.18]    Предсказание: True
# Входные данные [0.61, 1.0]    Предсказание: False
# Входные данные [-0.1, 0.29]    Предсказание: False
# Входные данные [-0.1, 0.08]    Предсказание: False
# Входные данные [0.1, 1.23]    Предсказание: True
# Входные данные [-0.38, 1.3]    Предсказание: True
# Входные данные [0.73, -0.15]    Предсказание: True
# Входные данные [0.96, 0.42]    Предсказание: True
# Входные данные [-0.25, 0.55]    Предсказание: True
# Входные данные [1.15, 0.15]    Предсказание: True
# Входные данные [-0.39, -0.17]    Предсказание: False
# Входные данные [1.01, 1.11]    Предсказание: False
# Входные данные [1.3, 1.11]    Предсказание: False
# Входные данные [0.03, 0.41000000000000003]    Предсказание: False
# Входные данные [0.75, -0.04]    Предсказание: True
# Входные данные [-0.02, 0.71]    Предсказание: True
# Входные данные [1.3, 0.86]    Предсказание: False
# Входные данные [-0.45, 1.4]    Предсказание: True
# Входные данные [-0.12, 1.31]    Предсказание: True
# Входные данные [1.3900000000000001, 0.45]    Предсказание: True
# Входные данные [-0.44, 1.16]    Предсказание: True
# Входные данные [1.37, -0.24]    Предсказание: True
# Входные данные [0.56, 0.13]    Предсказание: True
# Входные данные [0.88, -0.14]    Предсказание: True
# Входные данные [0.9299999999999999, 0.8]    Предсказание: False
# Входные данные [0.14, 0.16]    Предсказание: False
# Входные данные [0.98, -0.18]    Предсказание: True
# Входные данные [0.79, 0.31]    Предсказание: True
# Входные данные [0.88, -0.35000000000000003]    Предсказание: True
# Входные данные [0.29, 1.45]    Предсказание: True
# Входные данные [1.3900000000000001, -0.25]    Предсказание: True
# Входные данные [1.08, -0.06]    Предсказание: True
# Входные данные [-0.2, 1.27]    Предсказание: True
# Входные данные [1.09, -0.38]    Предсказание: True
# Входные данные [1.25, -0.2]    Предсказание: True
# Входные данные [-0.25, 0.13]    Предсказание: False
# Входные данные [0.92, 0.31]    Предсказание: True
# Входные данные [0.12, 0.31]    Предсказание: False
# Входные данные [1.29, 0.06]    Предсказание: True
# Входные данные [0.78, 0.62]    Предсказание: False
# Входные данные [-0.38, 0.05]    Предсказание: False
# Входные данные [-0.25, 1.02]    Предсказание: True
# Входные данные [1.24, 0.81]    Предсказание: False
# Входные данные [0.81, 0.88]    Предсказание: False
# Входные данные [0.03, 0.2]    Предсказание: False
# Входные данные [1.4, 0.83]    Предсказание: False
# Входные данные [0.41000000000000003, 0.01]    Предсказание: False
# Входные данные [-0.45, 1.31]    Предсказание: True
# Входные данные [0.72, -0.26]    Предсказание: True
# Входные данные [-0.18, 0.39]    Предсказание: False
# Входные данные [0.6699999999999999, 0.63]    Предсказание: False
# Входные данные [1.27, -0.4]    Предсказание: True
# Входные данные [1.32, -0.09]    Предсказание: True
# Входные данные [-0.12, -0.36]    Предсказание: False
# Входные данные [-0.2, -0.33]    Предсказание: False
# Входные данные [1.0, 0.6799999999999999]    Предсказание: False
# Входные данные [0.87, -0.08]    Предсказание: True
# Входные данные [0.84, 0.6599999999999999]    Предсказание: False
# Входные данные [0.03, 1.35]    Предсказание: True
# Входные данные [1.22, 0.88]    Предсказание: False
# Входные данные [-0.36, 0.97]    Предсказание: True
# Входные данные [0.05, 0.76]    Предсказание: True
# Входные данные [-0.15, -0.38]    Предсказание: False
# Входные данные [-0.24, -0.03]    Предсказание: False
# Входные данные [1.0, -0.15]    Предсказание: True
# Входные данные [-0.11, -0.1]    Предсказание: False
# Входные данные [0.36, 1.07]    Предсказание: True
# Входные данные [1.03, 0.88]    Предсказание: False
# Входные данные [-0.41000000000000003, 0.6699999999999999]    Предсказание: True
# Входные данные [0.03, 0.15]    Предсказание: False
# Входные данные [0.1, 0.59]    Предсказание: True
# Входные данные [1.42, 0.11]    Предсказание: True
# Входные данные [0.97, 0.39]    Предсказание: True
# Входные данные [0.17, -0.09]    Предсказание: False
# Входные данные [0.86, 0.71]    Предсказание: False
# Входные данные [0.09, -0.43]    Предсказание: False
# Входные данные [0.61, -0.13]    Предсказание: True
# Входные данные [-0.11, 1.1]    Предсказание: True
# Входные данные [0.42, -0.23]    Предсказание: False
# Входные данные [1.32, 1.31]    Предсказание: False
# Входные данные [-0.06, 1.23]    Предсказание: True
# Входные данные [-0.29, 0.41000000000000003]    Предсказание: False
# Входные данные [1.24, 1.26]    Предсказание: False
# Входные данные [1.45, 0.11]    Предсказание: True
# Входные данные [0.83, 0.3]    Предсказание: True
# Входные данные [0.03, -0.39]    Предсказание: False
# Входные данные [0.89, 0.9]    Предсказание: False
# Входные данные [0.21, -0.07]    Предсказание: False
# Входные данные [0.39, 1.01]    Предсказание: True
# Входные данные [-0.36, 0.78]    Предсказание: True
# Входные данные [-0.06, 0.75]    Предсказание: True
# Входные данные [1.45, 1.15]    Предсказание: False
# Входные данные [1.07, -0.18]    Предсказание: True
# Входные данные [0.99, -0.36]    Предсказание: True
# Входные данные [0.78, 0.62]    Предсказание: False
# Входные данные [-0.27, 0.6599999999999999]    Предсказание: True
# Входные данные [0.76, 1.43]    Предсказание: False
# Входные данные [-0.14, -0.3]    Предсказание: False
# Входные данные [1.4, 0.13]    Предсказание: True
# Входные данные [0.56, -0.03]    Предсказание: True
# Входные данные [0.59, -0.41000000000000003]    Предсказание: True
# Входные данные [1.15, 0.24]    Предсказание: True
# Входные данные [-0.05, 0.95]    Предсказание: True
# [[1.]
#  [1.]]
# Accurancy:  1.0
